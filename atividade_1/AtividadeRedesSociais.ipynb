# %% [markdown]
# ### TIAS
#
# Carol
# TIA 318.4734-1
#
# Daniel
# TIA 316.8767-9
#
# Caio
# TIA 318.9136-5
#
# Lucas
# TIA 415.5288-1

# %%
import matplotlib.pyplot as plt

y = [10,14,19,17,17,13,10]
x = ["13 a 17","18 a 24","25 a 34","35 a 44","45 a 54","55 a 64","acima de 65"]

plt.xlabel('Idade')
plt.ylabel('Porcentagem(%)')
plt.title('Distribuição de Idade dos usuários do Facebook')

plt.bar(x, y, align="center", color="red")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y = [10,18,22,17,15,11,7]
x = ["13 a 17","18 a 24","25 a 34","35 a 44","45 a 54","55 a 64","acima de 65"]

plt.xlabel('Idade')
plt.ylabel('Porcentagem(%)')
plt.title('Distribuição de Idade dos usuários do Twitter')
plt.bar(x, y, align="center", color="cyan")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y = [4,10,20,18,20,17,11]
x = ["13 a 17","18 a 24","25 a 34","35 a 44","45 a 54","55 a 64","acima de 65"]

plt.xlabel('Idade')
plt.ylabel('Porcentagem(%)')
plt.title('Distribuição de Idade dos usuários do Linkedin')

plt.bar(x, y, align="center", color="blue")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 7
Z = np.ones(n)
Z = (10,14,19,17,17,13,10)
plt.axes([0.025,0.025,0.95,0.95])
plt.title('Gráfico de Setores para o Facebook', fontsize=20);

plt.pie(Z)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 7
Z = np.ones(n)
Z = (4,10,20,18,20,11,17)
plt.axes([0.025,0.025,0.95,0.95])
plt.title('Gráfico de Setores para o Linkedin', fontsize=20);

plt.pie(Z)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 7
Z = (10,18,22,17,15,11,7)
plt.axes([0.025,0.025,0.95,0.95])
plt.title('Gráfico de Setores para o Twitter', fontsize = 20);


plt.pie(Z)
plt.show()

# %% [markdown]
# #### Diferenças entre os grupos (B)
# Linkedin tem uma proporção de público mais jovem relativamente pequena em relação ao Twitter e Facebook - o que faz sentido, tendo em vista que a rede social é usada para networking profissional.
#
# E comparando Facebook e Twitter diretamente, temos o Facebook com um público melhor distribuído entre as várias faixa etárias, quando comparado ao Twitter que tem uma maior parte de seu público entre os jovens adultos.
#
# #### Comparação entre os uso dos dois gráficos (C)
# O gráfico de setores evidência a diferença nítida entre as idades, porém dificulta muito para analisarmos entre os diferentes sites e plataformas.
# E para pequenas medidas ou diferenças pequenas entre um dado e outro o gráfico de barras acaba sendo melhor pela exatidão
